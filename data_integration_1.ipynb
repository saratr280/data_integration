# %%
import pandas as pd

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
census_data = pd.read_csv("acs2017_census_tract_data.csv")
census_data.head(10)
# Out:
#       TractId    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0  1001020100  Alabama  Autauga      1845   899    946       2.4   86.3
# 1  1001020200  Alabama  Autauga      2172  1167   1005       1.1   41.6
# 2  1001020300  Alabama  Autauga      3385  1533   1852       8.0   61.4
# 3  1001020400  Alabama  Autauga      4267  2001   2266       9.6   80.3
# 4  1001020500  Alabama  Autauga      9965  5054   4911       0.9   77.5
# 5  1001020600  Alabama  Autauga      3620  1765   1855       3.0   70.7
# 6  1001020700  Alabama  Autauga      3420  1459   1961       4.0   78.0
# 7  1001020801  Alabama  Autauga      2913  1495   1418       4.2   86.3
# 8  1001020802  Alabama  Autauga     11333  5488   5845       1.4   81.8
# 9  1001020900  Alabama  Autauga      6167  3111   3056       1.0   86.2
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0    5.2     0.0  ...   0.5          0.0         2.1         24.5       881
# ...

# %%
covid_data = pd.read_csv("COVID_county_data.csv")
covid_data.head(10)
# Out:
#          date       county       state     fips  cases  deaths
# 0  2020-01-21    Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22    Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23    Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24         Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24    Snohomish  Washington  53061.0      1     0.0
# 5  2020-01-25       Orange  California   6059.0      1     0.0
# 6  2020-01-25         Cook    Illinois  17031.0      1     0.0
# 7  2020-01-25    Snohomish  Washington  53061.0      1     0.0
# 8  2020-01-26     Maricopa     Arizona   4013.0      1     0.0
# 9  2020-01-26  Los Angeles  California   6037.0      1     0.0

# %%
covid_data = covid_data.rename(columns={"state": "State", "county": "County"})
covid_data.head()
# Out:
#          date     County       State     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
census_data.groupby(["State","County"]).sum()
# Out:
#                          TractId  TotalPop    Men   Women  Hispanic   White  \
# State   County
# Alabama Autauga      12012247403     55036  26899   28137      37.1   867.9
#         Baldwin      32097330873    203360  99527  103833     124.4  2580.6
#         Barbour       9053554500     26201  13976   12225      36.5   414.2
#         Bibb          4028040010     22580  12251   10329       8.9   317.6
#         Blount        9081453506     57667  28490   29177      88.8   779.8
# ...                          ...       ...    ...     ...       ...     ...
# Wyoming Sweetwater  672455650809     44527  22981   21546     191.4   959.3
#         Teton       224159870803     22923  12169   10754      56.1   330.3
#         Uinta       168125925900     20758  10593   10165      26.6   263.8
#         Washakie    168129000803      8253   4118    4135      44.1   245.3
#         Weston      112091902400      7117   3756    3361       3.1   183.0
#
# ...

# %%
covid_data.groupby(["State","County"]).sum()
# Out:
#                         fips    cases   deaths
# State   County
# Alabama Autauga     334334.0   645935   9042.0
#         Baldwin     345032.0  2003567  23041.0
#         Barbour     325620.0   268771   4077.0
#         Bibb        330296.0   261043   5272.0
#         Blount      335997.0   630106   8669.0
# ...                      ...      ...      ...
# Wyoming Teton     19053260.0   305376    617.0
#         Uinta     18213325.0   200783   1037.0
#         Unknown          0.0       37      0.0
#         Washakie  18550233.0    84354   2622.0
#         Weston    15132150.0    56976    286.0
#
# [3274 rows x 3 columns]

# %%
joined_data = pd.merge(census_data.groupby(["State","County"]).sum(),covid_data.groupby(["State","County"]).sum(),how="inner",on=["State","County"])
joined_data
# Out:
#                          TractId  TotalPop    Men   Women  Hispanic   White  \
# State   County
# Alabama Autauga      12012247403     55036  26899   28137      37.1   867.9
#         Baldwin      32097330873    203360  99527  103833     124.4  2580.6
#         Barbour       9053554500     26201  13976   12225      36.5   414.2
#         Bibb          4028040010     22580  12251   10329       8.9   317.6
#         Blount        9081453506     57667  28490   29177      88.8   779.8
# ...                          ...       ...    ...     ...       ...     ...
# Wyoming Sweetwater  672455650809     44527  22981   21546     191.4   959.3
#         Teton       224159870803     22923  12169   10754      56.1   330.3
#         Uinta       168125925900     20758  10593   10165      26.6   263.8
#         Washakie    168129000803      8253   4118    4135      44.1   245.3
#         Weston      112091902400      7117   3756    3361       3.1   183.0
#
# ...
